# %% [markdown]
# **Lesson: M931LT1 Artificial Intelligence II**
#
# **Student's name: Christina Christodoulou**
#
# **I.D Number: LT1200027**
#
# **Field of Studies: Language Technology**
#
# **Homework 4**
#
# **Question 3**

# %% [markdown]
# **QUESTION-ANSWERING OF SQuAD 2.0 BY FINE-TUNING BERT**

# %% [markdown]
# In this assignment, the pretrained **BERT**-base (**B**idirectional **E**ncoder **R**epresentations from **T**ransformers) model is fine-tuned for an NLP task using Python and the Pytorch library, namely **question answering**. The aim of this task is for BERT to be able to find the span of text in a provided passage that corresponds to the correct answer in a given question.
#
# BERT input:
#
# * The question and the passage containing the answer are needed as input. They are separated by the special [SEP] token.
#
# * The segment embeddings to differentiate the question from the passage. These are two embeddings (for segments 'A' and 'B') that BERT learned, and which are added to the token embeddings before feeding them into the input layer.

# %% [markdown]
# **DOWNLOAD AND IMPORT NECESSARY LIBRARIES AND PACKAGES**

# %%
# !pip install transformers datasets==1.5.0 wget
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.12.2)
# Requirement already satisfied: datasets==1.5.0 in /usr/local/lib/python3.7/dist-packages (1.5.0)
# Collecting wget
#   Downloading wget-3.2.zip (10 kB)
# Requirement already satisfied: tqdm<4.50.0,>=4.27 in /usr/local/lib/python3.7/dist-packages (from datasets==1.5.0) (4.49.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.7/dist-packages (from datasets==1.5.0) (2022.2.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets==1.5.0) (3.0.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.5.0) (2.23.0)
# Requirement already satisfied: pyarrow>=0.17.1 in /usr/local/lib/python3.7/dist-packages (from datasets==1.5.0) (6.0.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets==1.5.0) (1.3.5)
# Requirement already satisfied: huggingface-hub<0.1.0 in /usr/local/lib/python3.7/dist-packages (from datasets==1.5.0) (0.0.19)
# Requirement already satisfied: dill in /usr/local/lib/python3.7/dist-packages (from datasets==1.5.0) (0.3.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets==1.5.0) (1.21.5)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets==1.5.0) (4.11.2)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets==1.5.0) (0.70.12.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<0.1.0->datasets==1.5.0) (21.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<0.1.0->datasets==1.5.0) (3.10.0.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<0.1.0->datasets==1.5.0) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<0.1.0->datasets==1.5.0) (3.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.9->huggingface-hub<0.1.0->datasets==1.5.0) (3.0.7)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.5.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.5.0) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.5.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets==1.5.0) (2.10)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.7/dist-packages (from transformers) (0.0.47)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.10.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets==1.5.0) (3.7.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets==1.5.0) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets==1.5.0) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets==1.5.0) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.1.0)
# Building wheels for collected packages: wget
#   Building wheel for wget (setup.py) ... done
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9675 sha256=d4df3dfef6002be538d5467239ab30b0fd548b2409c7d8e9576aed2643fdd59b
#   Stored in directory: /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02
# Successfully built wget
# Installing collected packages: wget
# Successfully installed wget-3.2

# %%
# Import necessary libraries
import json
import textwrap
from pathlib import Path
import torch
import os
import timeit
from transformers import BertForQuestionAnswering, get_linear_schedule_with_warmup, AdamW, AutoTokenizer
from transformers.data.metrics.squad_metrics import compute_predictions_logits, squad_evaluate
from torch.utils.data import DataLoader, RandomSampler, SequentialSampler
from tqdm import tqdm
import random
import seaborn as sns
import re
import string 
import time
import datetime
import numpy as np
from sklearn.metrics import accuracy_score,  classification_report, precision_recall_fscore_support as score
import matplotlib.pyplot as plt 
import pandas as pd  
import torch.nn as nn
from collections import Counter

# %% [markdown]
# **SET UP GPU FOR TRAINING**

# %%
if torch.cuda.is_available():       
    device = torch.device("cuda")
    print(f'There are {torch.cuda.device_count()} GPU(s) available.')
    print('Device name:', torch.cuda.get_device_name(0))

else:
    print('No GPU available, using the CPU instead.')
    device = torch.device('cpu')
# Out:
# No GPU available, using the CPU instead.

# %% [markdown]
# **DOWNLOAD THE SQuAD 2.0 DATASET**

# %% [markdown]
# **QA dataset: SQuAD**
#
# One of the most popular datasets for Question-Answering is the Stanford Question Answering Dataset, or SQuAD, which comes in two versions: SQuAD 1.1 and SQuAD 2.0. These reading comprehension datasets consist of questions posed on a set of Wikipedia articles, where the answer to every question is a segment (or span) of the corresponding passage. In SQuAD 1.1, all questions have an answer in the corresponding passage. SQuAD 2.0 steps up the difficulty by including 50,000 unanswerable questions written by crowd workers. The SQuAD dataset comes in json format and it includes several layers like 'data', 'paragraphs', 'qas' that lead to 3 main parts:
#
# * **Question**: strings containing the question that are asked to the model to find the answer.
#
# * **Context**: larger segments of text that contain the answers to the questions.
#
# * **Answers**: shorter strings which are extracted from the given contexts and provide the answers to the questions.

# %%
if not os.path.exists('SQuAD'):
    os.mkdir('SQuAD')

DATA_DIR = 'SQuAD' 

def download_squad(version = 1):
  
  if version == 1:
    # !wget -P $DATA_DIR https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v1.1.json
    # !wget -P $DATA_DIR https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v1.1.json
  else:
    # !wget -P $DATA_DIR https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v2.0.json
    # !wget -P $DATA_DIR https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v2.0.json
    
  print('SQuAD dataset downloaded.')   

# Run the function       
download_squad(version = 2)
# Out:
# --2022-03-03 17:56:14--  https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v2.0.json
# Resolving rajpurkar.github.io (rajpurkar.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to rajpurkar.github.io (rajpurkar.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42123633 (40M) [application/json]
# Saving to: ‘SQuAD/train-v2.0.json’
#
# train-v2.0.json     100%[===================>]  40.17M   212MB/s    in 0.2s
#
# 2022-03-03 17:56:15 (212 MB/s) - ‘SQuAD/train-v2.0.json’ saved [42123633/42123633]
#
# --2022-03-03 17:56:15--  https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v2.0.json
# Resolving rajpurkar.github.io (rajpurkar.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to rajpurkar.github.io (rajpurkar.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4370528 (4.2M) [application/json]
# Saving to: ‘SQuAD/dev-v2.0.json’
#
# dev-v2.0.json       100%[===================>]   4.17M  --.-KB/s    in 0.05s
#
# 2022-03-03 17:56:15 (89.0 MB/s) - ‘SQuAD/dev-v2.0.json’ saved [4370528/4370528]
#
# SQuAD dataset downloaded.

# %% [markdown]
# **SET UP THE BERT PRETRAINED MODEL AND ITS TOKENIZER**

# %%
# Define the pre-trained model from Hugging Face and its tokenizer
model_name = 'bert-base-uncased'

# Loading the model
model = BertForQuestionAnswering.from_pretrained(model_name).to(device)

# Loading its tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)
# Out:
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/420M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForQuestionAnswering: ['cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertForQuestionAnswering from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForQuestionAnswering from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]

# %% [markdown]
# **FUNCTIONS AND CLASSES USED FOR DATA PREPARATION**

# %%
# A function stores the texts, questions and answers from the train and validation .json files into lists
def get_store_SQuAD_data(file_path):
  
  # Open .json file 
  file = open(file_path, 'rb')   
  squad_dict = json.load(file)

  # Initialize empty lists to fill in the contexts, questions and answers
  contexts = []
  questions = []
  answers = []

  # Iterate through the data for each passage, its question and its answer
  for group in squad_dict['data']:  
      for passage in group['paragraphs']:
          context = passage['context']
          for qa in passage['qas']:
              question = qa['question']
              
              # check if we need to be extracting from 'answers' or 'plausible_answers'
              if 'plausible_answers' in qa.keys():
                access = 'plausible_answers'
              else:
                access = 'answers'

              for answer in qa['answers']:      
                  # Fill the empty lists with every passage, question and its answer
                  contexts.append(context)
                  questions.append(question)
                  answers.append(answer)

  print('Length of texts:', len(contexts))
  print('Length of questions:', len(questions))
  print('Length of answers:', len(answers))

  return contexts, questions, answers

# %%
# A function that finds the end position of an answer and may cut the passage to be the same as the given answer to create appropriate input for BERT
def add_end_position(answers, contexts):
    
  # loop through each answer-context pair
  for answer, context in zip(answers, contexts):
      # answer_from_passage refers to the expected answer found in context
      answer_from_passage = answer['text']
      # The start index was already given
      start_idx = answer['answer_start']
      # It is time to get the end index according to the start index and the length of the answer
      end_idx = start_idx + len(answer_from_passage)

      # But, sometimes squad answers are off by a character or two
      if context[start_idx:end_idx] == answer_from_passage:
          # Get the end index if the answer is not off
          answer['answer_end'] = end_idx
      else:
          # The answer is off by 1-2 tokens
          for i in [1, 2]:
          # Cut the passage by 1 or 2 tokens to be the same as the given answer to create appropriate input for BERT
              if context[start_idx-i:end_idx-i] == answer_from_passage:
                  answer['answer_start'] = start_idx - i
                  answer['answer_end'] = end_idx - i

# %%
# A function that finds the start and end position of the answer
def add_token_positions(encodings, answers):
  
  # Initialize lists to fill in the token index of answer start/end
  start_positions = []
  end_positions = []

  count = 0

  for i in range(len(answers)):
    # Append start/end token position using the char_to_token method
    start_positions.append(encodings.char_to_token(i, answers[i]['answer_start']))
    end_positions.append(encodings.char_to_token(i, answers[i]['answer_end']))

    # In case there is not start position, then the answer passage has been truncated
    if start_positions[-1] is None:
      start_positions[-1] = tokenizer.model_max_length
      
    # In case the end position is None, the 'char_to_token' function points to the space after the correct token, so add - 1 
    if end_positions[-1] is None:
      end_positions[-1] = encodings.char_to_token(i, answers[i]['answer_end'] - 1)
      
      # In case the end position is still None the answer passage has been truncated
      if end_positions[-1] is None:
        count += 1
        end_positions[-1] = tokenizer.model_max_length

  print('Cases where the end position was None:',count)

  # Update the data in dictionary
  encodings.update({'start_positions': start_positions, 'end_positions': end_positions})

# %%
# A class that prepares the dataset by getting the inputs in tensors for BERT
class Prepare_Dataset(torch.utils.data.Dataset):
  
  def __init__(self, encodings):
    self.encodings = encodings

  def __len__(self):
    return len(self.encodings.input_ids)
    
  def __getitem__(self, idx):
    return {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}

# %% [markdown]
# **DATA PREPARATION**

# %%
print('Storing the passages, questions and answers of the training dataset...\n')

# Get and store the content of the json file into separate lists
train_passages, train_questions, train_answers = get_store_SQuAD_data('SQuAD/train-v2.0.json')

# View some examples
print('\nPassage:', train_passages[2])
print()
print('Question:', train_questions[2])
print()
print('Answer:', train_answers[2])
# Out:
# Storing the passages, questions and answers of the training dataset...
#
# Length of texts: 86821
# Length of questions: 86821
# Length of answers: 86821
#
# Passage: Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child. Managed by her father, Mathew Knowles, the group became one of the world's best-selling girl groups of all time. Their hiatus saw the release of Beyoncé's debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".
#
# Question: When did Beyonce leave Destiny's Child and become a solo singer?
#
# Answer: {'text': '2003', 'answer_start': 526}

# %%
print('Storing the passages, questions and answers of the validation dataset...\n')

# Get and store the content of the json file into separate lists
validation_passages, validation_questions, validation_answers = get_store_SQuAD_data('SQuAD/dev-v2.0.json')

# View some examples
print('\nPassage:', validation_passages[2])
print()
print('Question:', validation_questions[2])
print()
print('Answer:', validation_answers[2])
# Out:
# Storing the passages, questions and answers of the validation dataset...
#
# Length of texts: 20302
# Length of questions: 20302
# Length of answers: 20302
#
# Passage: The Normans (Norman: Nourmands; French: Normands; Latin: Normanni) were the people who in the 10th and 11th centuries gave their name to Normandy, a region in France. They were descended from Norse ("Norman" comes from "Norseman") raiders and pirates from Denmark, Iceland and Norway who, under their leader Rollo, agreed to swear fealty to King Charles III of West Francia. Through generations of assimilation and mixing with the native Frankish and Roman-Gaulish populations, their descendants would gradually merge with the Carolingian-based cultures of West Francia. The distinct cultural and ethnic identity of the Normans emerged initially in the first half of the 10th century, and it continued to evolve over the succeeding centuries.
#
# Question: In what country is Normandy located?
#
# Answer: {'text': 'France', 'answer_start': 159}

# %%
print('Preparing the training dataset...\n')

# Get the end position from the passages
add_end_position(train_answers, train_passages)

# Tokenize the data using BERT'S tokenizer
train_encodings = tokenizer(train_passages, 
                            train_questions, 
                            truncation = True,
                            max_length = 384,
                            stride = 128,  
                            padding = 'max_length')

# Add the batch of start and end position                           
add_token_positions(train_encodings, train_answers)

# Prepare the dataset in the appropriate input for BERT
train_dataset = Prepare_Dataset(train_encodings)

# Create the train batches and take random samples
train_dataloader = DataLoader(train_dataset, batch_size = 16, sampler = RandomSampler(train_dataset), pin_memory = True)
print('The train data are ready for training.')
# Out:
# Preparing the training dataset...
#
# Cases where the end position was None: 75
# The train data are ready for training.

# %%
print('Preparing the validation dataset...\n')

# Get the end position from the passages
add_end_position(validation_answers, validation_passages)

# Tokenize the data using BERT'S tokenizer
val_encodings = tokenizer(validation_passages, 
                          validation_questions, 
                          truncation = True,
                          max_length = 384, 
                          stride = 128,  
                          padding = 'max_length')

# Add the batch of start and end position 
add_token_positions(val_encodings, validation_answers)

# Prepare the dataset in the appropriate input for BERT
val_dataset = Prepare_Dataset(val_encodings)

# Create the train batches and take sequential samples
val_dataloader = DataLoader(val_dataset, batch_size = 16, sampler = SequentialSampler(val_dataset), pin_memory = True)
print('The validation data are ready for evaluation.')
# Out:
# Preparing the validation dataset...
#
# Cases where the end position was None: 71
# The validation data are ready for evaluation.

# %% [markdown]
# **FUNCTIONS USED FOR MODEL FINETUNING, EVALUATION AND TESTING**

# %%
# A function that sets seed for reproducibility
def set_seed(seed_value): 
    random.seed(seed_value)
    np.random.seed(seed_value)
    torch.manual_seed(seed_value)
    torch.cuda.manual_seed_all(seed_value)

# %%
# A function that calculates time in seconds and returns a string in the form hh:mm:ss
def calculate_time(elapsed_time):
   
    # Round to the nearest second
    elapsed_rounded = int(round((elapsed_time)))
    
    # Format as hh:mm:ss
    return str(datetime.timedelta(seconds=elapsed_rounded))

# %%
def train_evaluate(model, train_dataloader, valid_dataloader, optimizer, scheduler, epochs):
  
  print('Training model in {} sentences and evaluating model in {} sentences...'.format(len(train_dataloader), len(valid_dataloader)))
  # Store losses and accuracies
  training_stats = []

  # Measure the total training and evaluation time
  total_t0 = time.time()

  for epoch in range(0, epochs):
    print('\n======== EPOCH {} / {} ========\n'.format(epoch + 1, epochs))
    print('TRAINING MODEL...') 
    
    # Measure how long the training epoch takes
    t0 = time.time()

    training_loss = 0
      
    model.train()
    
    for step, batch in enumerate(train_dataloader):

      # Progress update every 603 batches 
      if step % 603 == 0 and not step == 0:
        
        # Calculate elapsed time in minutes
        elapsed = calculate_time(time.time() - t0)
              
        # Report progress
        print(f'Batch {step} of {len(train_dataloader)} | Elapsed time: {elapsed}')
       
      input_ids = batch['input_ids'].to(device)
      attention_masks = batch['attention_mask'].to(device)
      start_positions = batch['start_positions'].to(device)
      end_positions = batch['end_positions'].to(device)
                   
      # Zero the gradients
      optimizer.zero_grad()
      
      # Perform forward propagation. Compute the predictions                            
      predictions = model(input_ids, attention_mask = attention_masks, start_positions = start_positions, end_positions = end_positions)

      # Get the loss
      loss = predictions[0]

      # Perform backward propagation
      loss.backward()
           
      # Clip the gradient value
      nn.utils.clip_grad_norm_(model.parameters(), max_norm = 1.0) # Avoid exploding of gradients
          
      # Use optimizer to take gradient step
      optimizer.step()
      
      # Update the learning rate
      scheduler.step()

      training_loss += loss.item()
      
    train_loss_of_epoch = training_loss / len(train_dataloader)
              
    # Measure the epoch training time
    training_time = calculate_time(time.time() - t0)
    
    print('Training epoch time: {} | Train Loss: {:.3f}'.format(training_time, train_loss_of_epoch))
    
    print('\nEVALUATING MODEL...')
    
    t0 = time.time()

    model.eval()  

    eval_loss = 0
    accuracy = []
    
    # Calculation of gradient not required during evaluation 
    with torch.no_grad():  
    
      for batch in valid_dataloader:       
        input_id = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        start_true = batch['start_positions'].to(device)
        end_true = batch['end_positions'].to(device)
                
        # Perform forward propagation
        outputs = model(input_id, attention_mask = attention_mask, start_positions = start_true, end_positions = end_true)
                        
        # Get the loss
        losses = outputs[0]        
        
        eval_loss += losses.item()

        # pull prediction tensors out and argmax to get predicted tokens
        start_pred = torch.argmax(outputs['start_logits'], dim=1)
        end_pred = torch.argmax(outputs['end_logits'], dim=1)
        
        # calculate accuracy for both and append to accuracy list
        accuracy.append(((start_pred == start_true).sum()/len(start_pred)).item())
        accuracy.append(((end_pred == end_true).sum()/len(end_pred)).item())
        
    # calculate average accuracy in total
    accuracy_score = np.sum(accuracy) / len(accuracy)
           
    loss_of_epoch_val = eval_loss / len(valid_dataloader)
    
    # Measure the validating epoch time
    validation_time = calculate_time(time.time() - t0)

    print('Validation epoch time: {} | Validation Loss: {:.3f} | Validation Accuracy: {:.2f}%'.format(validation_time, loss_of_epoch_val, accuracy_score))

    # Record all statistics from each epoch
    training_stats.append({'Epoch': epoch + 1,
                            'Training Loss': train_loss_of_epoch,
                            'Validation Loss': loss_of_epoch_val,
                            'Training Time': training_time,
                            'Validation Time': validation_time,
                            'Validation Accuracy': accuracy_score})
  
  print('Training and evaluation process complete!')

  print('Total amount of time: {}'.format(calculate_time(time.time()-total_t0)))

  return training_stats, model

# %% [markdown]
# **PREPARE THE NECESSARY PARAMETERS FOR TRAINING AND EVALUATION**

# %%
# Set seed for reproducibility
set_seed(42)    

# Define number of training epochs
epochs = 2

# Prepare optimizer and schedule (linear warmup and decay)
no_decay = ["bias", "LayerNorm.weight"]

optimizer_grouped_parameters = [{"params": [p for n, p in model.named_parameters() if not any(nd in n for nd in no_decay)],
                                "weight_decay": 0.0},
                                {"params": [p for n, p in model.named_parameters() if any(nd in n for nd in no_decay)], "weight_decay": 0.0}]

# Define the optimizer and its parameters
optimizer = torch.optim.AdamW(optimizer_grouped_parameters, lr = 3e-5, eps = 1e-8)

# Total number of training steps
total_steps = len(train_dataloader) * epochs

# Set up the learning rate scheduler
scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps = 0, num_training_steps = total_steps)

# %% [markdown]
# **FINETUNE AND EVALUATE BERT MODEL**

# %%
training_statistics, finetuned_model = train_evaluate(model, train_dataloader, val_dataloader, optimizer, scheduler, epochs)
# Out:
# Training model in 5427 sentences and evaluating model in 1269 sentences...
#
# ======== EPOCH 1 / 2 ========
#
# TRAINING MODEL...
# Batch 603 of 5427 | Elapsed time: 0:11:39
# Batch 1206 of 5427 | Elapsed time: 0:23:36
# Batch 1809 of 5427 | Elapsed time: 0:35:50
# Batch 2412 of 5427 | Elapsed time: 0:48:04
# Batch 3015 of 5427 | Elapsed time: 1:00:18
# Batch 3618 of 5427 | Elapsed time: 1:12:33
# Batch 4221 of 5427 | Elapsed time: 1:24:47
# Batch 4824 of 5427 | Elapsed time: 1:37:01
# Training epoch time: 1:49:14 | Train Loss: 1.311
#
# EVALUATING MODEL...
# Validation epoch time: 0:09:21 | Validation Loss: 1.103 | Validation Accuracy: 0.69%
#
# ======== EPOCH 2 / 2 ========
#
# TRAINING MODEL...
# Batch 603 of 5427 | Elapsed time: 0:12:14
# Batch 1206 of 5427 | Elapsed time: 0:24:28
# Batch 1809 of 5427 | Elapsed time: 0:36:42
# Batch 2412 of 5427 | Elapsed time: 0:48:57
# Batch 3015 of 5427 | Elapsed time: 1:01:11
# Batch 3618 of 5427 | Elapsed time: 1:13:25
# Batch 4221 of 5427 | Elapsed time: 1:25:39
# Batch 4824 of 5427 | Elapsed time: 1:37:54
# Training epoch time: 1:50:09 | Train Loss: 0.724
#
# EVALUATING MODEL...
# Validation epoch time: 0:09:23 | Validation Loss: 1.099 | Validation Accuracy: 0.70%
# Training and evaluation process complete!
# Total amount of time: 3:58:07

# %%
# Display floats with two decimal places
pd.set_option('precision', 2)

# Create a DataFrame from our training statistics
df_stats = pd.DataFrame(data = training_statistics)

# Use the 'epoch' as the row index
df_stats = df_stats.set_index('Epoch')

# Display the table
df_stats
# Out:
#        Training Loss  Validation Loss  ... Validation Time Validation Accuracy
# Epoch                                  ...
# 1               1.31              1.1  ...         0:09:21                0.69
# 2               0.72              1.1  ...         0:09:23                0.70
#
# [2 rows x 5 columns]

# %%
# Use plot styling from seaborn
sns.set(style='darkgrid')

# Increase the plot size and font size
sns.set(font_scale=1.5)
plt.rcParams['figure.figsize'] = (12,6)

# Plot the learning curve of loss
plt.plot(df_stats['Training Loss'], 'b-o', label='Training')
plt.plot(df_stats['Validation Loss'], 'g-o', label='Validation')
plt.title('Training & Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.xticks([1, 2, 3, 4])
plt.show()

# %% [markdown]
# **SAVE THE FINETUNED MODEL**

# %%
torch.save(finetuned_model, 'SQuAD_2.0_BERT_model_384.pt')

# Create output directory if needed
output_dir = 'BERT_outputs'

if not os.path.exists(output_dir):

    os.makedirs(output_dir)

print('Saving model checkpoint to: ', output_dir)

# Save a trained model, configuration and tokenizer using 'save_pretrained()'.

# They can then be reloaded using 'from_pretrained()'

model_to_save = finetuned_model.module if hasattr(finetuned_model, 'module') else finetuned_model  # Take care of distributed/parallel training

model_to_save.save_pretrained(output_dir)

tokenizer.save_pretrained(output_dir)
# Out:
# Saving model checkpoint to:  BERT_outputs
# ('BERT_outputs/tokenizer_config.json',
#  'BERT_outputs/special_tokens_map.json',
#  'BERT_outputs/vocab.txt',
#  'BERT_outputs/added_tokens.json',
#  'BERT_outputs/tokenizer.json')

# %% [markdown]
# **LOAD THE FINETUNED MODEL**

# %%
# In case you want to load to model using the cpu use the command below:
model = torch.load('SQuAD_2.0_BERT_model_384.pt', map_location=torch.device('cpu'))
model.eval()

# Loading its tokenizer
tokenizer = AutoTokenizer.from_pretrained('bert-base-uncased')

# Loading the model
#model = BertForQuestionAnswering.from_pretrained(output_dir).to(device)

# %% [markdown]
# **FUNCTIONS USED FOR MODEL TESTING**

# %%
#=== Data preparation ===

# A function that applies preprocessing steps to a given text (for the context and its predicted answer) 
def normalize_answer(s):
  
  def remove_articles(text):
    return re.sub(r'\b(a|an|the)\b', ' ', text)
    
  def white_space_fix(text):
    return ' '.join(text.split())
      
  def remove_punc(text):
    exclude = set(string.punctuation)
    return ''.join(ch for ch in text if ch not in exclude)

  def lower(text):
      return text.lower()

  return white_space_fix(remove_articles(remove_punc(lower(s))))

# %%
#=== Metric calculation ===

# A function that computes the exact match of the predicted answer and the true answer in the passage
def compute_exact_match(predicted_answer, true_answer):
  
  return int(normalize_answer(predicted_answer) == normalize_answer(true_answer))


# A function that calculates the precision, recall and the f1 score of the predicted and the true answer in the passage
def compute_metrics(predicted_answer, true_answer):
    
  predicted_tokens = normalize_answer(predicted_answer).split()
  true_tokens = normalize_answer(true_answer).split()
    
  common_tokens = Counter(true_tokens) & Counter(predicted_tokens)
  numbers_of_same = sum(common_tokens.values())

  # if either the prediction or the truth is no-answer then f1 = 1 if they agree, 0 otherwise
  if len(true_tokens) == 0 or len(predicted_tokens) == 0:
    return int(true_tokens == predicted_tokens)

  if numbers_of_same == 0:
    return 0

  precision = 1.0 * numbers_of_same / len(predicted_tokens)
  recall = 1.0 * numbers_of_same / len(true_tokens)
  score_f1 = (2 * precision * recall) / (precision + recall)

  return score_f1

# %%
def question_answering(context, question):

  inputs = tokenizer.encode_plus(question, context, return_tensors = "pt", max_length= 384, padding = "max_length", stride = 128, truncation = True)

  outputs = model(**inputs)
  answer_start = torch.argmax(outputs[0])  # get the most likely beginning of answer with the argmax of the score
  answer_end = torch.argmax(outputs[1]) + 1 

  answer = tokenizer.convert_tokens_to_string(tokenizer.convert_ids_to_tokens(inputs['input_ids'][0][answer_start:answer_end]))

  Exact_match_score = compute_exact_match(answer, context)
  F1_score = compute_metrics(answer, context)
  
  print('\nQuestion:', question)
  print('\nAnswer: "' + answer + '"')
  print('Exact Match {} | F1 score {}'.format(Exact_match_score, F1_score))

  return answer

# %% [markdown]
# **QUESTION ANSWERING: TEST THE BERT MODEL**

# %%
# Wrap text to 100 characters

wrapper = textwrap.TextWrapper(width=100) 

bert_abstract = "We introduce a new language representation model called BERT, which stands for Bidirectional Encoder Representations from Transformers. Unlike recent language representation models (Peters et al., 2018a; Radford et al., 2018), BERT is designed to pretrain deep bidirectional representations from unlabeled text by jointly conditioning on both left and right context in all layers. As a result, the pre-trained BERT model can be finetuned with just one additional output layer to create state-of-the-art models for a wide range of tasks, such as question answering and language inference, without substantial taskspecific architecture modifications. BERT is conceptually simple and empirically powerful. It obtains new state-of-the-art results on eleven natural language processing tasks, including pushing the GLUE score to 80.5% (7.7% point absolute improvement), MultiNLI accuracy to 86.7% (4.6% absolute improvement), SQuAD v1.1 question answering Test F1 to 93.2 (1.5 point absolute improvement) and SQuAD v2.0 Test F1 to 83.1 (5.1 point absolute improvement)."

print(wrapper.fill(bert_abstract))

questions_bert_abstract = ["What does the 'B' in BERT stand for?", "What does BERT stand for?"]

for question in questions_bert_abstract:
  question_answering(bert_abstract, question)
# Out:
# We introduce a new language representation model called BERT, which stands for Bidirectional Encoder
# Representations from Transformers. Unlike recent language representation models (Peters et al.,
# 2018a; Radford et al., 2018), BERT is designed to pretrain deep bidirectional representations from
# unlabeled text by jointly conditioning on both left and right context in all layers. As a result,
# the pre-trained BERT model can be finetuned with just one additional output layer to create state-
# of-the-art models for a wide range of tasks, such as question answering and language inference,
# without substantial taskspecific architecture modifications. BERT is conceptually simple and
# empirically powerful. It obtains new state-of-the-art results on eleven natural language processing
# tasks, including pushing the GLUE score to 80.5% (7.7% point absolute improvement), MultiNLI
# accuracy to 86.7% (4.6% absolute improvement), SQuAD v1.1 question answering Test F1 to 93.2 (1.5
# point absolute improvement) and SQuAD v2.0 Test F1 to 83.1 (5.1 point absolute improvement).
#
# Question: What does the 'B' in BERT stand for?
#
# Answer: "bidirectional encoder representations from transformers."
# Exact Match 0 | F1 score 0.06666666666666667
#
# Question: What does BERT stand for?
#
# Answer: "bidirectional encoder representations from transformers."
# Exact Match 0 | F1 score 0.06666666666666667

# %%
# Wrap text to 100 characters

wrapper = textwrap.TextWrapper(width=100) 

question_answering_art_abstract = "Extractive reading comprehension systems can often locate the correct answer to a question in a context document, but they also tend to make unreliable guesses on questions for which the correct answer is not stated in the context. Existing datasets either focus exclusively on answerable questions, or use automatically generated unanswerable questions that are easy to identify. To address these weaknesses, we present SQuAD 2.0, the latest version of the Stanford Question Answering Dataset (SQuAD). SQuAD 2.0 combines existing SQuAD data with over 50,000 unanswerable questions written adversarially by crowdworkers to look similar to answerable ones. To do well on SQuAD 2.0, systems must not only answer questions when possible, but also determine when no answer is supported by the paragraph and abstain from answering. SQuAD 2.0 is a challenging natural language understanding task for existing models: a strong neural system that gets 86% F1 on SQuAD 1.1 achieves only 66% F1 on SQuAD 2.0."

print(wrapper.fill(question_answering_art_abstract))

question1 = "What is SQuAD 2.0?"

question_answering(question_answering_art_abstract, question1)
# Out:
# Extractive reading comprehension systems can often locate the correct answer to a question in a
# context document, but they also tend to make unreliable guesses on questions for which the correct
# answer is not stated in the context. Existing datasets either focus exclusively on answerable
# questions, or use automatically generated unanswerable questions that are easy to identify. To
# address these weaknesses, we present SQuAD 2.0, the latest version of the Stanford Question
# Answering Dataset (SQuAD). SQuAD 2.0 combines existing SQuAD data with over 50,000 unanswerable
# questions written adversarially by crowdworkers to look similar to answerable ones. To do well on
# SQuAD 2.0, systems must not only answer questions when possible, but also determine when no answer
# is supported by the paragraph and abstain from answering. SQuAD 2.0 is a challenging natural
# language understanding task for existing models: a strong neural system that gets 86% F1 on SQuAD
# 1.1 achieves only 66% F1 on SQuAD 2.0.
#
# Question: What is SQuAD 2.0?
#
# Answer: ""
# Exact Match 0 | F1 score 0
# ''

# %%
wrapper = textwrap.TextWrapper(width=100) 

question_answering_art_abstract = "Hello, my name is Christina Christodoulou. I am from Greece and I live in Athens. I study at IT in the University of Athens. I am currently doing my Master's in 'Language Technology'."

print(wrapper.fill(question_answering_art_abstract))

questions_student = ["What is her name?", "Where is she from?", "Is she Greek?", "Where does she live?", "In what university does she study?", "What is the Master's name?"]

for question in questions_student: 
  question_answering(question_answering_art_abstract, question)
# Out:
# Hello, my name is Christina Christodoulou. I am from Greece and I live in Athens. I study at IT in
# the University of Athens. I am currently doing my Master's in 'Language Technology'.
#
# Question: What is her name?
#
# Answer: "christina christodoulou."
# Exact Match 0 | F1 score 0.11764705882352941
#
# Question: Where is she from?
#
# Answer: "greece"
# Exact Match 0 | F1 score 0.06060606060606061
#
# Question: Is she Greek?
#
# Answer: "christina christodoulou. i am from greece and i live in athens."
# Exact Match 0 | F1 score 0.5116279069767442
#
# Question: Where does she live?
#
# Answer: "athens."
# Exact Match 0 | F1 score 0.06060606060606061
#
# Question: In what university does she study?
#
# Answer: "university of athens."
# Exact Match 0 | F1 score 0.17142857142857143
#
# Question: What is the Master's name?
#
# Answer: "christina christodoulou."
# Exact Match 0 | F1 score 0.11764705882352941

# %% [markdown]
# **TESTING THE MODEL WITH YOUR OWN EXAMPLES (USER INPUT)**

# %%
text = input('Please enter your text without quotation marks: \n')
question = input('\nPlease enter your question without quotation marks: \n')

while True:
  question_answering(question, text)
    
  flag = True
  flag_N = False
    
  while flag:
    response = input("\nDo you want to ask another question based on this text (Y/N)? ")
    if response[0] == "Y":
      question = input("\nPlease enter your question: \n")
      flag = False
    elif response[0] == "N":
      print("\nBye!")
      flag = False
      flag_N = True
            
  if flag_N == True:
    exit()

# %% [markdown]
# **DOWNLOAD TRIVIA QA**

# %%
import datasets

# Download Trivia QA using the datasets library (not all of it due to memory limit issues)
validation_dataset = datasets.load_dataset("trivia_qa", "rc", split="validation[:1000]")
# Out:
# Reusing dataset trivia_qa (/root/.cache/huggingface/datasets/trivia_qa/rc/1.1.0/c1b17d80bfdd2f43b13e4b5741847f704115379ecebcb21e0917d2e8ddaa1ff1)

# %%
# View the content of the Triva QA
validation_dataset
# Out:
# Dataset({
#     features: ['question', 'question_id', 'question_source', 'entity_pages', 'search_results', 'answer'],
#     num_rows: 1000
# })

# %%
# Look at its features
validation_dataset.info.features
# Out:
# {'answer': {'aliases': Sequence(feature=Value(dtype='string', id=None), length=-1, id=None),
#   'matched_wiki_entity_name': Value(dtype='string', id=None),
#   'normalized_aliases': Sequence(feature=Value(dtype='string', id=None), length=-1, id=None),
#   'normalized_matched_wiki_entity_name': Value(dtype='string', id=None),
#   'normalized_value': Value(dtype='string', id=None),
#   'type': Value(dtype='string', id=None),
#   'value': Value(dtype='string', id=None)},
#  'entity_pages': Sequence(feature={'doc_source': Value(dtype='string', id=None), 'filename': Value(dtype='string', id=None), 'title': Value(dtype='string', id=None), 'wiki_context': Value(dtype='string', id=None)}, length=-1, id=None),
#  'question': Value(dtype='string', id=None),
#  'question_id': Value(dtype='string', id=None),
#  'question_source': Value(dtype='string', id=None),
#  'search_results': Sequence(feature={'description': Value(dtype='string', id=None), 'filename': Value(dtype='string', id=None), 'rank': Value(dtype='int32', id=None), 'title': Value(dtype='string', id=None), 'url': Value(dtype='string', id=None), 'search_context': Value(dtype='string', id=None)}, length=-1, id=None)}

# %% [markdown]
# **FUNCTIONS USED FOR TRIVIAQA**

# %%
# A function that merges the contents under a single category
def format_dataset(example):
  
  example["context"] = " ".join(("\n".join(example["entity_pages"]["wiki_context"])).split("\n"))
  example["possible_answers"] = example["answer"]["aliases"]
  example["correct_answer"] = example["answer"]["normalized_value"]

  return example

# %%
# A function that computes the predicted answers for the trivia dataset and gives answer, EM and F1 score
def question_answering_trivia(question, context):

  with torch.no_grad():
    
    inputs = tokenizer.encode_plus(question, context, return_tensors="pt", max_length= 384, padding="max_length", stride = 128, truncation=True)

    outputs = model(**inputs)
    answer_start = torch.argmax(outputs[0])  # get the most likely beginning of answer with the argmax of the score
    answer_end = torch.argmax(outputs[1]) + 1 

    answer = tokenizer.convert_tokens_to_string(tokenizer.convert_ids_to_tokens(inputs['input_ids'][0][answer_start:answer_end]))

    Exact_match_score = compute_exact_match(answer, str(context))
    F1_score = compute_metrics(answer, str(context))

    print('\nQuestion:', question)
    print('\nAnswer: "' + answer + '"')
    print('Exact Match {} | F1 score {}'.format(Exact_match_score, F1_score))

# %%
exclude_punctuation = set(''.join(['‘', '’', '´', '`', '.', ',', '-', '"']))

def get_sub_answers(answers, begin = 0, end = None):
  
  return [" ".join(x.split(" ")[begin:end]) for x in answers if len(x.split(" ")) > 1]


def expand_to_aliases(given_answers, make_sub_answers=False):
  
  if make_sub_answers:
    # if answers are longer than one word, make sure a prediction is correct if it coresponds to the complete 1: or :-1 sub word
    given_answers = given_answers + get_sub_answers(given_answers, begin=1) + get_sub_answers(given_answers, end=-1)
  
  answers = []
  
  for answer in given_answers:
    alias = answer.replace('_', ' ').lower()
    alias = ''.join(c if c not in exclude_punctuation else ' ' for c in alias)
    answers.append(' '.join(alias.split()).strip())
  
  return set(answers)


def get_best_valid_start_end_idx(start_scores, end_scores, top_k = 1, max_size = 100):
  
  best_start_scores, best_start_idx = torch.topk(start_scores, top_k)
  best_end_scores, best_end_idx = torch.topk(end_scores, top_k)

  widths = best_end_idx[:, None] - best_start_idx[None, :]
  mask = torch.logical_or(widths < 0, widths > max_size)
  scores = (best_end_scores[:, None] + best_start_scores[None, :]) - (1e8 * mask)
  best_score = torch.argmax(scores).item()

  return best_start_idx[best_score % top_k], best_end_idx[best_score // top_k]

# %%
# A function that evaluates the results of the Trivia QA dataset in a dictionary form and returns exact match and F1 score
def evaluate_result(example):
  
  encoding = tokenizer(example["question"], example["context"], return_tensors="pt", max_length= 384, padding="max_length", stride = 128, truncation=True)
  input_ids = encoding.input_ids
  
  with torch.no_grad():
      start_scores, end_scores = model(input_ids=input_ids).to_tuple()

  start_score, end_score = get_best_valid_start_end_idx(start_scores[0], end_scores[0], top_k=8, max_size=16)

  # Convert the input ids back to actual tokens 
  all_tokens = tokenizer.convert_ids_to_tokens(encoding["input_ids"][0].tolist())
  answer_tokens = all_tokens[start_score: end_score + 1]

  example["output"] = tokenizer.decode(tokenizer.convert_tokens_to_ids(answer_tokens))

  answers = expand_to_aliases(example["possible_answers"], make_sub_answers=True)
  predictions = expand_to_aliases([example["output"]])

  # if there is a common element, it's a match
  example["match"] = len(list(answers & predictions)) > 0

  return example

# %%
# Apply the function and delete unecessary columns
trivia_qa_dataset = validation_dataset.map(format_dataset, remove_columns=["search_results", "question_source", "entity_pages", "answer", "question_id"])
# Out:
# Loading cached processed dataset at /root/.cache/huggingface/datasets/trivia_qa/rc/1.1.0/c1b17d80bfdd2f43b13e4b5741847f704115379ecebcb21e0917d2e8ddaa1ff1/cache-3bf6f5421ea0d3ee.arrow

# %% [markdown]
# Some samples may have an empty context. For those samples the correct answer from the context is impossible to be extracted for the context is empty. Thus, those samples are filtered out using the filter() function offered by datasets.

# %%
trivia_qa_dataset = trivia_qa_dataset.filter(lambda x: len(x["context"]) > 0)

trivia_qa_dataset
# Out:
# Loading cached processed dataset at /root/.cache/huggingface/datasets/trivia_qa/rc/1.1.0/c1b17d80bfdd2f43b13e4b5741847f704115379ecebcb21e0917d2e8ddaa1ff1/cache-622b5acda47f53bb.arrow
# Dataset({
#     features: ['context', 'correct_answer', 'possible_answers', 'question'],
#     num_rows: 580
# })

# %% [markdown]
# **RESULTS ON THE WHOLE TRIVIAQA DATASET**

# %%
# Compute the results of all the TriviaQA dataset from a dictionary form
results = trivia_qa_dataset.map(evaluate_result)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=580.0), HTML(value='')))

# %%
print("Exact Match: {:.2f}".format(100 * sum(results['match'])/len(results)))
# Out:
# Exact Match: 11.38

# %% [markdown]
# **INSPECT THE RESULTS ON THE TRIVIAQA DATASET**

# %%
wrong_results = results.filter(lambda x: x['match'] is False)
print(f"\nWrong examples: ")
print_out = wrong_results.map(lambda x, i: print(f"{i} - Predicted answer: {x['output']} - Correct answer: {x['correct_answer']}"), with_indices = True)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1.0), HTML(value='')))
# Wrong examples:
# 0 - Predicted answer: the capital is london, - Correct answer: coventry
# HBox(children=(FloatProgress(value=0.0, max=514.0), HTML(value='')))
# 0 - Predicted answer: the capital is london, - Correct answer: coventry
# 1 - Predicted answer: it created an income stream, - Correct answer: norwegian
# 2 - Predicted answer: hertford loop - Correct answer: mallard
# 3 - Predicted answer: the play begins when a designated member of the fielding team, known as the bowler, - Correct answer: handling ball
# 4 - Predicted answer: [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] - Correct answer: dr finlay
# 5 - Predicted answer: tony blackburn, - Correct answer: nick grimshaw
# 6 - Predicted answer: delting dolphins - Correct answer: shetland
# 7 - Predicted answer: britain and its empire fought a successful war against germany, italy and japan. - Correct answer: george iii
# 8 - Predicted answer: [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] - Correct answer: m61
# 9 - Predicted answer: the london underground - Correct answer: piccadilly
# 10 - Predicted answer: refusal of conventional sexual relations to have provoked her incest, - Correct answer: adonis
# 11 - Predicted answer: uranus is similar in composition to neptune, - Correct answer: neptune
# 12 - Predicted answer: graphite may be considered the highest grade of coal, just above anthracite - Correct answer: golf
# 13 - Predicted answer: rupert is considered to have been a quick - thinking and energetic cavalry general, - Correct answer: hudson s bay company
# 14 - Predicted answer: the tendency of particular cognitive experiences to provoke laughter and provide amusement. - Correct answer: pun
# 15 - Predicted answer: tennis - Correct answer: fred perry
# 16 - Predicted answer: september 5, 1847 - april 3, 1882 ) - Correct answer: 1869
# 17 - Predicted answer: al - khwarizmi. - Correct answer: alan turing
# 18 - Predicted answer: amerindians, mestizos, europeans, asians and africans. - Correct answer: andes
# 19 - Predicted answer: purple is the color most often associated with royalty, magic, mystery and piety. - Correct answer: quinine
# 20 - Predicted answer: lumiere brothers'cinematographe - Correct answer: film making
# 21 - Predicted answer: jack kirby. - Correct answer: loki
# 22 - Predicted answer: it became the autonomous republic of crimea - Correct answer: ukraine
# 23 - Predicted answer: large - scale military deployment of fighters beyond lebanon's borders. - Correct answer: party of god
# 24 - Predicted answer: william shakespeare - Correct answer: m69
# 25 - Predicted answer: mexica people of tenochtitlan - Correct answer: montezuma
# 26 - Predicted answer: house of hanover. - Correct answer: queen victoria
# 27 - Predicted answer: italian libya colony - Correct answer: italy
# 28 - Predicted answer: george ( 1784 – 1855 ), minister at scoonie, fife ; - Correct answer: kaleidoscope
# 29 - Predicted answer: fruit and vegetables, - Correct answer: fruit
# 30 - Predicted answer: serekhs, representing the king's palace - Correct answer: red
# 31 - Predicted answer: mozart, - Correct answer: igor stravinsky
# 32 - Predicted answer: dog catcher for the local animal shelter. - Correct answer: french connection
# 33 - Predicted answer: species within the genus capparis are highly variable, - Correct answer: puttanesca
# 34 - Predicted answer: chad obtained independence under the leadership of francois tombalbaye. - Correct answer: niger
# 35 - Predicted answer: french revolution - Correct answer: waterloo
# 36 - Predicted answer: royal shakespeare company and its predecessors in stratford - upon - avon since 1879. - Correct answer: gertrude
# 37 - Predicted answer: a third full term. - Correct answer: gerald ford
# 38 - Predicted answer: austria - hungary delivered an ultimatum to the kingdom of serbia, - Correct answer: ypres
# 39 - Predicted answer: johnny khan, - Correct answer: calypso
# 40 - Predicted answer: cheetahs are induced ovulators, - Correct answer: honey badger
# 41 - Predicted answer: roman track - Correct answer: king baudouin stadium
# 42 - Predicted answer: ice is considered a mineral. - Correct answer: snow
# 43 - Predicted answer: gentle - Correct answer: rabbit
# 44 - Predicted answer: it was over by the december, 1991 dissolution of the soviet union, - Correct answer: skylab
# 45 - Predicted answer: the first location in santa barbara had no restaurant on - site, - Correct answer: motel 6
# 46 - Predicted answer: tennis is played by millions of recreational players and is also a popular worldwide spectator sport. - Correct answer: martina hingis
# 47 - Predicted answer: lightweight baby buggy - Correct answer: baby buggy
# 48 - Predicted answer: the dynasty was split between austrian and spanish branches. - Correct answer: switzerland
# 49 - Predicted answer: steroid hormones, - Correct answer: luteinizing hormone
# 50 - Predicted answer: the milky way is estimated to contain 100 – 400 billion stars, - Correct answer: local galaxy
# 51 - Predicted answer: unangam - Correct answer: mount mckinley
# 52 - Predicted answer: atlanta - Correct answer: chicago
# 53 - Predicted answer: he typically wears a sailor shirt and cap with a bow tie. - Correct answer: huey dewey and louie
# 54 - Predicted answer: in march 1890, the secretary of renton - Correct answer: 3
# 55 - Predicted answer: buddy holly and the big bopper - Correct answer: richie valens
# 56 - Predicted answer: did not know the gun was loaded - Correct answer: fort boyard
# 57 - Predicted answer: castor was the mortal son of tyndareus, the king of sparta, - Correct answer: castor
# 58 - Predicted answer: short, portly man who uses specialized, high - tech umbrellas as weapons. - Correct answer: penguin
# 59 - Predicted answer: fish - Correct answer: lungs
# 60 - Predicted answer: great white shark attacks beachgoers on amity island, - Correct answer: bruce
# 61 - Predicted answer: clifford charles devlin " cliff " thorburn - Correct answer: cliff thorburn
# 62 - Predicted answer: junket, - Correct answer: rennet
# 63 - Predicted answer: supermarine aviation works, which operated as a subsidiary of vickers - armstrong - Correct answer: supermarine
# 64 - Predicted answer: uk and the rest of europe, comic strips are also serialized in comic book magazines, - Correct answer: dennis menace
# 65 - Predicted answer: cool jazz - Correct answer: charlie parker
# 66 - Predicted answer: catatonia - Correct answer: baby it s cold outside
# 67 - Predicted answer: steve biko and his friend donald woods, - Correct answer: steve biko
# 68 - Predicted answer: this boat was successfully tested on dalswinton loch near ellisland - Correct answer: scotland
# 69 - Predicted answer: sloth bears prefer termites and ants - Correct answer: bear
# 70 - Predicted answer: catherine de'medici, - Correct answer: pyotr tchaikovsky
# 71 - Predicted answer: sindhi people, - Correct answer: pakistan
# 72 - Predicted answer: some leaves, such as bulb scales - Correct answer: eucalyptus
# 73 - Predicted answer: vice president of the united states. - Correct answer: lyndon b johnson
# 74 - Predicted answer: 51 cm - Correct answer: business
# 75 - Predicted answer: nootka cypress, - Correct answer: absinthe
# 76 - Predicted answer: peter, a judge, presiding in calgary, and a sister catherine. - Correct answer: canada
# 77 - Predicted answer: internazionale - Correct answer: italy
# 78 - Predicted answer: rock and metal. - Correct answer: hydrogen
# 79 - Predicted answer: football in the united kingdom and mainly soccer in canada and the united states. - Correct answer: cambridge
# 80 - Predicted answer: they descend from a common ancestor, but don't include all its descendants. - Correct answer: pig
# 81 - Predicted answer: nathaniel poe, - Correct answer: hawkeye
# 82 - Predicted answer: united states of america - walt disney ' - Correct answer: gregory peck
# 83 - Predicted answer: changing societal attitudes, - Correct answer: 15 years
# 84 - Predicted answer: letters patent - Correct answer: ely
# 85 - Predicted answer: larvae progress through four distinct growth stages ( instars ) - Correct answer: potato
# 86 - Predicted answer: humbert humbert, is obsessed with the 12 - year - old dolores haze, - Correct answer: lolita
# 87 - Predicted answer: bunter's defining characteristic is his greediness and dramatically overweight appearance. - Correct answer: quelch
# 88 - Predicted answer: the seax has a lasting symbolic impact in the english counties of essex and middlesex, - Correct answer: mercia
# 89 - Predicted answer: two - cylinder temperino, - Correct answer: formula one
# 90 - Predicted answer: kendo nagasaki. - Correct answer: martin ruane
# 91 - Predicted answer: most games are played on saturday and sunday afternoons ; - Correct answer: blackburn rovers
# 92 - Predicted answer: " premium " squares, - Correct answer: five
# 93 - Predicted answer: arthur kipps, - Correct answer: kipps
# 94 - Predicted answer: bananarama, - Correct answer: shakespeare s sister
# 95 - Predicted answer: socrates, parmenides, heraclitus and pythagoras, - Correct answer: socrates
# 96 - Predicted answer: le moribond ", originally by belgian singer jacques brel from 1962. - Correct answer: seasons in sun
# 97 - Predicted answer: to stimulate the appetite, - Correct answer: dubonnet
# 98 - Predicted answer: maxi - scooters, - Correct answer: vespa
# 99 - Predicted answer: western and central europe, - Correct answer: stanislas wawrinka
# 100 - Predicted answer: abraham martin - Correct answer: montcalm
# 101 - Predicted answer: bing russell ( 1926 – 2003 ) and dancer louise julia ( crone ) russell. - Correct answer: goldie hawn
# 102 - Predicted answer: it supports the structures of the face and provides a protective cavity for the brain. - Correct answer: fontanelle
# 103 - Predicted answer: the royal navy maintains a fleet of technologically sophisticated ships and submarines - Correct answer: ludo
# 104 - Predicted answer: mcdonald's is the world's second largest private employer — behind walmart — - Correct answer: ray croc
# 105 - Predicted answer: a number of distinct rock music subgenres had emerged, - Correct answer: sydney
# 106 - Predicted answer: does not allow shear waves - Correct answer: mantle
# 107 - Predicted answer: chief ministers, - Correct answer: spain
# 108 - Predicted answer: thomas richard arthur blair, was a clergyman. - Correct answer: george orwell
# 109 - Predicted answer: clouded leopard - Correct answer: wild cat
# 110 - Predicted answer: douglas fairbanks. - Correct answer: 451
# 111 - Predicted answer: oceanography and biogeochemistry. - Correct answer: rainfall
# 112 - Predicted answer: scarlet - Correct answer: red
# 113 - Predicted answer: oxygen - Correct answer: copper
# 114 - Predicted answer: passenger or cargo boat. - Correct answer: wind
# 115 - Predicted answer: moving death march - Correct answer: 120
# 116 - Predicted answer: 70 - Correct answer: allergic reaction
# 117 - Predicted answer: mexican revolution of 1910, - Correct answer: spanish
# 118 - Predicted answer: the racecourse has undergone a facelift in recent years, - Correct answer: horseracing
# 119 - Predicted answer: this album featured the only track to be written by all five members of the band. - Correct answer: music
# 120 - Predicted answer: callanetics exercises. - Correct answer: fitness
# 121 - Predicted answer: zancle - Correct answer: sicily
# 122 - Predicted answer: ethnic enclaves assist members in achieving economic mobility. - Correct answer: surrounded
# 123 - Predicted answer: it is the third largest country in africa. - Correct answer: khartoum
# 124 - Predicted answer: the private life of henry viii by nancy brysson morrison. - Correct answer: rick wakeman
# 125 - Predicted answer: team orders - Correct answer: france
# 126 - Predicted answer: ireland in ireland, - Correct answer: wales
# 127 - Predicted answer: colombia. - Correct answer: venezuela
# 128 - Predicted answer: cooler and less saline, and floats over the warm, more saline mediterranean inflow – - Correct answer: black sea
# 129 - Predicted answer: rubber soles developed from used rubber car - tires. - Correct answer: foot
# 130 - Predicted answer: charles acquiesced to the clarendon code - Correct answer: hudson s bay company
# 131 - Predicted answer: the canary islands - Correct answer: dogs
# 132 - Predicted answer: paul tutmarc - Correct answer: john entwhistle
# 133 - Predicted answer: the championship has been held every four years since the inaugural tournament in 1950, - Correct answer: indianapolis usa
# 134 - Predicted answer: the permian is a geologic period and system which extends from to million years ago. - Correct answer: cretaceous
# 135 - Predicted answer: guy lombardo and his royal canadians serenaded canada on the cbc, - Correct answer: hogmanay
# 136 - Predicted answer: helped in the spread of christianity and the resolution of various doctrinal disputes. - Correct answer: st peter s rome
# 137 - Predicted answer: bunny hug " - Correct answer: usa
# 138 - Predicted answer: fleet street - Correct answer: fleet
# 139 - Predicted answer: energy from light is absorbed by proteins - Correct answer: starch
# 140 - Predicted answer: papua. - Correct answer: torres strait
# 141 - Predicted answer: 1662, - Correct answer: first daily newspaper
# 142 - Predicted answer: soviet union in 1976 and 1977. - Correct answer: usa
# 143 - Predicted answer: kevin spacey fowler - Correct answer: sam mendes
# 144 - Predicted answer: zeus - Correct answer: minos
# 145 - Predicted answer: number theory. - Correct answer: prime
# 146 - Predicted answer: greece and denmark - Correct answer: corfu
# 147 - Predicted answer: patriots drove the royal officials out of every colony - Correct answer: 3
# 148 - Predicted answer: wild drake - Correct answer: duck
# 149 - Predicted answer: the holy see currently maintain official diplomatic relations with the roc. - Correct answer: china
# 150 - Predicted answer: recouping its budget in two weeks - Correct answer: honor blackman
# 151 - Predicted answer: 21 october 1967 and 28 october 1967 ), peaked at number five on 22 november 1967 - Correct answer: four weddings and funeral
# 152 - Predicted answer: my gorge rises at it. - Correct answer: jester
# 153 - Predicted answer: zimbabwe and botswana - Correct answer: south africa
# 154 - Predicted answer: twenty - nine, - Correct answer: new zealand
# 155 - Predicted answer: the international rowing federation - Correct answer: leander club
# 156 - Predicted answer: in use since 1907 but differs only slightly from the version that was adopted in 1815. - Correct answer: netherlands
# 157 - Predicted answer: monthly - Correct answer: convict
# 158 - Predicted answer: he must be dead now. - Correct answer: madness
# 159 - Predicted answer: some prehistoric species are also known : * uria bordkorbi - Correct answer: seabird
# 160 - Predicted answer: congress - Correct answer: puerto rico
# 161 - Predicted answer: its attention to the concerns, passions, and suffering of average americans ; - Correct answer: harry angstrom
# 162 - Predicted answer: france - Correct answer: spain
# 163 - Predicted answer: a pyramid - Correct answer: aleister crowley
# 164 - Predicted answer: al - farooq terrorist training camp. - Correct answer: buffalo six
# 165 - Predicted answer: the romans believed they had colonized knossos. - Correct answer: labyrinth
# 166 - Predicted answer: plays on the stereotypical differences between canadian and american culture, - Correct answer: canada
# 167 - Predicted answer: 180 mi northeast of sable island on october 28, 1991. - Correct answer: perfect storm
# 168 - Predicted answer: $ 6. 46 billion, - Correct answer: episode iii revenge of sith
# 169 - Predicted answer: rules and changes to regulations are decided between the four entities, - Correct answer: jorge lorenzo
# 170 - Predicted answer: bengali muslim majority, - Correct answer: bengali
# 171 - Predicted answer: woodrow wilson " woody " guthrie - Correct answer: bound for glory
# 172 - Predicted answer: serenity, - Correct answer: outstanding special visual effects for series
# 173 - Predicted answer: both chariot and mounted horse racing were events in the ancient greek olympics by 648 bc - Correct answer: nightmarch
# 174 - Predicted answer: faith in jesus, - Correct answer: christianity
# 175 - Predicted answer: anna eleanor roosevelt - Correct answer: roosevelt
# 176 - Predicted answer: maybe sometime i go to italy - Correct answer: marx
# 177 - Predicted answer: gladiator - Correct answer: spartacus
# 178 - Predicted answer: francis, who was elected on 13 march 2013, succeeding benedict xvi. - Correct answer: pope benedict xvi
# 179 - Predicted answer: italian duchess catherine de'medici married the duke of orleans - Correct answer: vanilla
# 180 - Predicted answer: william kirby - Correct answer: insects
# 181 - Predicted answer: jesus responded by saying : " friend, do what you are here to do. " - Correct answer: judas iscariot
# 182 - Predicted answer: cantharellaceae. - Correct answer: mushroom
# 183 - Predicted answer: pipe organ and the harpsichord, - Correct answer: ebony
# 184 - Predicted answer: the oldest true fossils of baleen are only 15 million years old, - Correct answer: corset
# 185 - Predicted answer: the zambezi river - Correct answer: zambezi
# 186 - Predicted answer: richard bachman - Correct answer: stephen king
# 187 - Predicted answer: a song – - Correct answer: ned sherrin
# 188 - Predicted answer: his father was a roman catholic school inspector of czech origin named watzlawick - Correct answer: 1972
# 189 - Predicted answer: group leadership, - Correct answer: bernardo bertolucci
# 190 - Predicted answer: huntington ingalls industries, - Correct answer: harland wolff
# 191 - Predicted answer: the tate gallery announced that bankside would be the home for the new tate modern. - Correct answer: bankside power station
# 192 - Predicted answer: batswana - Correct answer: bechuanaland
# 193 - Predicted answer: jamal malik, age 18, from the juhu slums of mumbai. - Correct answer: mumbai
# 194 - Predicted answer: beaufort wind force scale. - Correct answer: 8
# 195 - Predicted answer: belfast international airport 15 mi west of the city. - Correct answer: george best
# 196 - Predicted answer: blunderstone rookery - Correct answer: wilkins
# 197 - Predicted answer: daddy ni by the family, was a coal - miner - Correct answer: jenkins
# 198 - Predicted answer: rosalind leigh, - Correct answer: pauline quirke
# 199 - Predicted answer: achilles tendon or heel cord, - Correct answer: paris
# 200 - Predicted answer: the general tendency has been toward centralization and incorporation, - Correct answer: new mexico
# 201 - Predicted answer: second wednesday - Correct answer: connecticut
# 202 - Predicted answer: bicycles ( only back ), buses, cars, golf carts - Correct answer: e
# 203 - Predicted answer: ferranti thistle, - Correct answer: livingston
# 204 - Predicted answer: edinburgh dog - Correct answer: greyfriars bobby
# 205 - Predicted answer: f - 7, - Correct answer: babes in arms
# 206 - Predicted answer: robert anthony de niro - Correct answer: jake la motta
# 207 - Predicted answer: it has also been broadcast on radio since 1927 ; - Correct answer: carberry
# 208 - Predicted answer: white and gray matter microscopically, there are differences between the neurons - Correct answer: parkinson s disease
# 209 - Predicted answer: painting was born in leamington spa, the son of a railway signalman. - Correct answer: phil archer
# 210 - Predicted answer: neep - Correct answer: swede
# 211 - Predicted answer: it was financed by the two bellamont sisters. - Correct answer: trent
# 212 - Predicted answer: early flutes - Correct answer: oboe
# 213 - Predicted answer: the 1952 prize to selman waksman - Correct answer: sir ronald ross
# 214 - Predicted answer: earth, air, fire, water - Correct answer: ether
# 215 - Predicted answer: none of the trees in the painting exist today. - Correct answer: willy lott
# 216 - Predicted answer: benvolio - Correct answer: romeo and juliet
# 217 - Predicted answer: monatomic noble gases ; - Correct answer: robert boyle
# 218 - Predicted answer: approximately 100, 000 dilmun burial mounds - Correct answer: bahrain
# 219 - Predicted answer: their classic line - up consisted of lead singer roger daltrey, - Correct answer: david bowie
# 220 - Predicted answer: leubronn, germany. - Correct answer: george eliot
# 221 - Predicted answer: dartmoor national park authority, - Correct answer: dartmoor
# 222 - Predicted answer: all english monarchs after 1066 ultimately claim descent from the normans ; - Correct answer: henry sixth
# 223 - Predicted answer: by hand and presented it to his sister mary louise baum brewster. - Correct answer: yellow bricks
# 224 - Predicted answer: mid - atlantic. - Correct answer: niagara falls
# 225 - Predicted answer: cough - Correct answer: high blood pressure
# 226 - Predicted answer: galt football club - Correct answer: ontario
# 227 - Predicted answer: widowed innkeeper, - Correct answer: almond
# 228 - Predicted answer: states range in population from just under 600, 000 ( wyoming ) - Correct answer: wyoming
# 229 - Predicted answer: catherine gordon - Correct answer: childe harold s
# 230 - Predicted answer: fruit and vegetables, - Correct answer: fruit
# 231 - Predicted answer: welsh immigrants settled in the area to work in nearby colleries. - Correct answer: alt
# 232 - Predicted answer: the nabateans - Correct answer: jordan
# 233 - Predicted answer: sir alfred joseph hitchcock, - Correct answer: daphne du maurier
# 234 - Predicted answer: vanellus vanellus ) - Correct answer: lapwing
# 235 - Predicted answer: parsley - Correct answer: onions
# 236 - Predicted answer: voltaire, - Correct answer: jaws
# 237 - Predicted answer: queen elizabeth ii who is the head of the commonwealth. - Correct answer: new zealand
# 238 - Predicted answer: zimbabwe ' - Correct answer: bangladesh
# 239 - Predicted answer: they were inducted into the rock and roll hall of fame in 1997 ; - Correct answer: isle of man
# 240 - Predicted answer: the copenhagen city council arranged to move the statue to shanghai - Correct answer: copenhagen
# 241 - Predicted answer: trifoliate, - Correct answer: yellow
# 242 - Predicted answer: native foods, - Correct answer: tamale
# 243 - Predicted answer: richmond thackeray - Correct answer: makepeace
# 244 - Predicted answer: bass clarinet - Correct answer: ottorino respighi
# 245 - Predicted answer: cheddar show caves, - Correct answer: mendips
# 246 - Predicted answer: michael gerard " mike " tyson - Correct answer: james buster douglas
# 247 - Predicted answer: by the 1830s the westminster system of government ( or cabinet government ) had emerged ; the prime minister had become primus inter pares or the first among equals in the cabinet and the head of government in the united kingdom. - Correct answer: jim callaghan
# 248 - Predicted answer: scotland was the first country to consider hosting the 2014 commonwealth games in 2004, - Correct answer: ibrox stadium
# 249 - Predicted answer: during march 2005 aviva acquired the rac plc breakdown recovery operation - Correct answer: aviva
# 250 - Predicted answer: 1971 amateur boxing association of england middleweight champion. - Correct answer: middleweight
# 251 - Predicted answer: venice - Correct answer: london
# 252 - Predicted answer: increasing costs and nearly destroying the life and career of francis ford coppola. - Correct answer: apocalypse now
# 253 - Predicted answer: [PAD] [PAD] [PAD] - Correct answer: stockholm
# 254 - Predicted answer: the simpson family, - Correct answer: rio
# 255 - Predicted answer: shoemaker's workshop - Correct answer: battle of agincourt 1415
# 256 - Predicted answer: zadok the priest, let thy hand be strengthened, - Correct answer: zadok priest
# 257 - Predicted answer: madonna ' - Correct answer: like prayer
# 258 - Predicted answer: transposons ' - Correct answer: jumping genes
# 259 - Predicted answer: fred karno company, - Correct answer: countess from hong kong
# 260 - Predicted answer: terminator ( 1984 ). - Correct answer: titanic
# 261 - Predicted answer: a wide variety of material has been published in newspapers. - Correct answer: guardian
# 262 - Predicted answer: it is the sixth - most populous country with a population exceeding 201 million people. - Correct answer: rawalpindi
# 263 - Predicted answer: henry was in france with the emperor maximilian at the siege of therouanne. - Correct answer: northumberland
# 264 - Predicted answer: chile pine ' - Correct answer: monkey puzzle
# 265 - Predicted answer: towards the end of the sixteenth century - Correct answer: lanzarote
# 266 - Predicted answer: [PAD] - Correct answer: volleyball
# 267 - Predicted answer: sir humphrey appleby, - Correct answer: administrative affairs
# 268 - Predicted answer: 5 – - Correct answer: sweden
# 269 - Predicted answer: william friese - greene filed a patent for a 3d movie process. - Correct answer: clash of titans
# 270 - Predicted answer: april 6 : capone * - Correct answer: john frankenheimer
# 271 - Predicted answer: operation weserubung, the german invasion of norway. - Correct answer: gneisenau
# 272 - Predicted answer: british airways london eye, - Correct answer: british airways
# 273 - Predicted answer: berber kingdom of mauretania, - Correct answer: mauretania
# 274 - Predicted answer: it had a population in 2011 of 3, 063, 456 - Correct answer: silurian
# 275 - Predicted answer: nick cotton - Correct answer: jim branning
# 276 - Predicted answer: no club from outside the top two divisions has reached the final. - Correct answer: wanderers
# 277 - Predicted answer: william gladstone. - Correct answer: palmerston
# 278 - Predicted answer: non - spontaneous reactions - Correct answer: catalyst
# 279 - Predicted answer: his funeral was an occasion of public mourning, - Correct answer: la boheme
# 280 - Predicted answer: trend - Correct answer: robert stroud
# 281 - Predicted answer: each of the ten generals would rotate as polemarch - Correct answer: squadron leader
# 282 - Predicted answer: red crossbill - Correct answer: finch
# 283 - Predicted answer: sony interactive entertainment. - Correct answer: sony
# 284 - Predicted answer: the son of caroline ( bright ), a philadelphia school board administrator, - Correct answer: independence day
# 285 - Predicted answer: the french revolution - Correct answer: marengo
# 286 - Predicted answer: saintpaulia ' - Correct answer: african violet
# 287 - Predicted answer: libya was an early center of christianity. - Correct answer: idris i
# 288 - Predicted answer: nancy anderson, - Correct answer: arthur ransome
# 289 - Predicted answer: 14 february 1779 ) - Correct answer: joseph banks
# 290 - Predicted answer: his father was an industrial personnel manager and his mother, - Correct answer: yardbirds
# 291 - Predicted answer: acids - Correct answer: tartaric acid
# 292 - Predicted answer: catalans - Correct answer: cyclades
# 293 - Predicted answer: quantum mechanics in the early - to - mid 20th century. - Correct answer: maxwell
# 294 - Predicted answer: australia is a member of the united nations, - Correct answer: nullarbor plain
# 295 - Predicted answer: wealthy yet declining upper - class family ; - Correct answer: turkey
# 296 - Predicted answer: franz theodor schubert, the son of a moravian peasant, was a parish schoolmaster ; - Correct answer: franz schubert
# 297 - Predicted answer: signs and symptoms symptoms of cmt usually begin in early childhood or early adulthood, - Correct answer: legs
# 298 - Predicted answer: punic wars ' - Correct answer: carthage
# 299 - Predicted answer: richard strauss ) - Correct answer: paul dukas
# 300 - Predicted answer: the declaration of independence - Correct answer: south carolina
# 301 - Predicted answer: aby rosen, - Correct answer: mark rothko
# 302 - Predicted answer: march 1982 to december 1982, - Correct answer: albert reynolds
# 303 - Predicted answer: guitar, keyboards, and harmonica. - Correct answer: joan baez
# 304 - Predicted answer: oklahoma is the 20th most extensive and the 28th most populous of the 50 united states. - Correct answer: alfred murrah federal building
# 305 - Predicted answer: cons $ 11, 000 - Correct answer: henry gondorf
# 306 - Predicted answer: suspicious foreigners setting fires. - Correct answer: pudding lane
# 307 - Predicted answer: most lochs that formerly hosted bonspiels, - Correct answer: curling
# 308 - Predicted answer: the war ended in 1783 - Correct answer: yellowstone park
# 309 - Predicted answer: in 1959, jones was signed to capitol records - Correct answer: donkey serenade
# 310 - Predicted answer: " wig " by " syrup " - Correct answer: telephone
# 311 - Predicted answer: their classic line - up consisted of lead singer roger daltrey, - Correct answer: john entwhistle
# 312 - Predicted answer: patella - Correct answer: spain
# 313 - Predicted answer: mozart was young, he and his sister marianne - Correct answer: diana ross
# 314 - Predicted answer: everton were founding members of the football league in 1888 - Correct answer: 1985
# 315 - Predicted answer: 1998 - Correct answer: 1955
# 316 - Predicted answer: cheltenham. - Correct answer: newbury
# 317 - Predicted answer: wendel phillips high school - Correct answer: mona lisa
# 318 - Predicted answer: earl hamner, jr., - Correct answer: ralph waite
# 319 - Predicted answer: harbeson, hough, livingston & larson - Correct answer: vancouver
# 320 - Predicted answer: equilateral triangle - Correct answer: isosceles triangle
# 321 - Predicted answer: tudor close - Correct answer: colonel mustard
# 322 - Predicted answer: mar del sur. - Correct answer: cape horn
# 323 - Predicted answer: major service providers. - Correct answer: too long didn t read
# 324 - Predicted answer: karate schools began appearing across the world, catering to those with casual interest - Correct answer: martial arts
# 325 - Predicted answer: it is the smallest bone in the body. - Correct answer: ear
# 326 - Predicted answer: old ironsides. - Correct answer: uss constitution
# 327 - Predicted answer: sleigh - bells " - Correct answer: brown
# 328 - Predicted answer: arts educational schools london, - Correct answer: sunset boulevard
# 329 - Predicted answer: arthur balfour - Correct answer: campbell bannerman
# 330 - Predicted answer: tiffany - Correct answer: exile
# 331 - Predicted answer: after winning a prestigious singing competition at the carlisle festival - Correct answer: cancer
# 332 - Predicted answer: bad ", " the way you make me feel " - Correct answer: moonwalk
# 333 - Predicted answer: plain rectangle - Correct answer: green
# 334 - Predicted answer: the princess theatre musicals - Correct answer: my fair lady
# 335 - Predicted answer: which highway - Correct answer: 61
# 336 - Predicted answer: soviet authorities collectivized agriculture, - Correct answer: rumania
# 337 - Predicted answer: southern illinois university carbondale with a degree in speech and theater arts. - Correct answer: wild palms
# 338 - Predicted answer: it is preceded by mutiny on the " bounty " - Correct answer: mutiny on bounty
# 339 - Predicted answer: truman streckfus persons, - Correct answer: persons
# 340 - Predicted answer: allegory for the search for happiness. - Correct answer: boojum
# 341 - Predicted answer: her parents were both originally from north dakota. - Correct answer: dangerous minds
# 342 - Predicted answer: leslie lynch king jr. - Correct answer: rudolph
# 343 - Predicted answer: traveling salesman. - Correct answer: architect
# 344 - Predicted answer: nick littlemore of electronic dance outfit pnau. - Correct answer: j g ballard
# 345 - Predicted answer: the pacers were eastern conference champions in 2000. - Correct answer: basketball
# 346 - Predicted answer: 1981. - Correct answer: stars on 45 medley
# 347 - Predicted answer: the country is officially bilingual at the federal level. - Correct answer: vancouver
# 348 - Predicted answer: acting. - Correct answer: kentuckian
# 349 - Predicted answer: the capital is london, - Correct answer: coventry
# 350 - Predicted answer: vase - paintings and votive gifts. - Correct answer: cyclopes
# 351 - Predicted answer: some factions of the shining path have functioned as a highly efficient cocaine - smuggling operation, - Correct answer: peru
# 352 - Predicted answer: 15. - Correct answer: 27
# 353 - Predicted answer: thrustssc. - Correct answer: richard noble
# 354 - Predicted answer: norfolk, virginia. - Correct answer: virginia
# 355 - Predicted answer: george marshall. - Correct answer: marshall plan
# 356 - Predicted answer: kung fu : the movie, - Correct answer: crow
# 357 - Predicted answer: ice cube - Correct answer: staple singers
# 358 - Predicted answer: mc hammer featuring saja aka sonia moore, - Correct answer: mc hammer
# 359 - Predicted answer: luanda, - Correct answer: angola
# 360 - Predicted answer: the supremes, - Correct answer: upside down
# 361 - Predicted answer: river of life - Correct answer: dark blood
# 362 - Predicted answer: the rca changed its regulations and awarded the diploma. - Correct answer: hockney
# 363 - Predicted answer: anne patricia - Correct answer: columcille
# 364 - Predicted answer: camille - Correct answer: grand hotel
# 365 - Predicted answer: the daily express. - Correct answer: cartoons
# 366 - Predicted answer: martina navratilova - Correct answer: virginia wade
# 367 - Predicted answer: willie park sr. - Correct answer: walter hagen
# 368 - Predicted answer: famous players - lasky corporation ) - Correct answer: famous players film company
# 369 - Predicted answer: it sits atop a featureless, barren, windswept and icy plateau - Correct answer: edmond hillary
# 370 - Predicted answer: lieutenant william calley jr., - Correct answer: seymour hersh
# 371 - Predicted answer: shirley conran - Correct answer: jasper
# 372 - Predicted answer: beatlemania. - Correct answer: pepsi
# 373 - Predicted answer: brian, - Correct answer: carl wilson
# 374 - Predicted answer: mark goodson - Correct answer: richard dawson
# 375 - Predicted answer: large male bear - Correct answer: bear cub
# 376 - Predicted answer: racist and anti - socialist views. - Correct answer: all in family
# 377 - Predicted answer: august 5, 1930 – august 25, 2012 ) - Correct answer: july 20th
# 378 - Predicted answer: history human settlement in brunei can be traced back as far as 6th and 7th century - Correct answer: brunei
# 379 - Predicted answer: photographer and filmmaker - Correct answer: photographer
# 380 - Predicted answer: donald sutherland and shirley douglas, - Correct answer: kiefer sutherland
# 381 - Predicted answer: two, - Correct answer: 10
# 382 - Predicted answer: mound building cultures. - Correct answer: ty cobb
# 383 - Predicted answer: old mother hubbard - Correct answer: jimi hendrix
# 384 - Predicted answer: [PAD] - Correct answer: donny osmond
# 385 - Predicted answer: sean john combs - Correct answer: mase
# 386 - Predicted answer: himalayan trust, - Correct answer: bee keeping
# 387 - Predicted answer: construction of a new international terminal, runway and apron. - Correct answer: libya
# 388 - Predicted answer: sethe's reincarnated daughter. - Correct answer: oprah winfrey
# 389 - Predicted answer: younger - Correct answer: leonard nimoy
# 390 - Predicted answer: george accepts nina's offer and moves into her apartment. - Correct answer: jennifer aniston
# 391 - Predicted answer: betty lou bredemus - Correct answer: tinkerbell
# 392 - Predicted answer: vice president of the united states. - Correct answer: nixon
# 393 - Predicted answer: the film director gives direction - Correct answer: roger corman
# 394 - Predicted answer: a conscientious attempt to be faithful to already known facts - Correct answer: alien
# 395 - Predicted answer: sir humphrey appleby, - Correct answer: george
# 396 - Predicted answer: sweden emerged as an independent and unified country during the middle ages. - Correct answer: ingrid bergman
# 397 - Predicted answer: it reached number 2 in the uk singles chart in 1975, - Correct answer: full monty
# 398 - Predicted answer: captive - Correct answer: crawford
# 399 - Predicted answer: cary grant, katharine hepburn, and james stewart and featuring ruth hussey. - Correct answer: james stewart
# 400 - Predicted answer: the lighting overloads the electrical system and roberts orders it shut off. - Correct answer: fred astaire
# 401 - Predicted answer: chicken ranch in la grange, texas. - Correct answer: chicken ranch
# 402 - Predicted answer: cervantes'life or of don quixote. - Correct answer: peter o toole
# 403 - Predicted answer: joely kim richardson - Correct answer: daughter
# 404 - Predicted answer: tennis is played by millions of recreational players and is also a popular worldwide spectator sport. - Correct answer: martina hingis
# 405 - Predicted answer: unemployed - Correct answer: belgium
# 406 - Predicted answer: eliminate jews - Correct answer: april 30th
# 407 - Predicted answer: colorado river, - Correct answer: colorado
# 408 - Predicted answer: english traders and settlers began to inhabit the region. - Correct answer: ryder cup
# 409 - Predicted answer: the herd " - Correct answer: 13
# 410 - Predicted answer: the african queen - Correct answer: guess who s coming to dinner
# 411 - Predicted answer: beatles songs - Correct answer: gary lewis and playboys
# 412 - Predicted answer: ukrainian soviet socialist republic of the soviet union - Correct answer: sweden
# 413 - Predicted answer: joseph stalin - Correct answer: andropov
# 414 - Predicted answer: lightweight baby buggy - Correct answer: baby buggy
# 415 - Predicted answer: christopher ford - Correct answer: harrison ford
# 416 - Predicted answer: inside - the - park " home run, - Correct answer: roger maris
# 417 - Predicted answer: new york mets and the victorious kansas city royals. - Correct answer: philadelphia phillies
# 418 - Predicted answer: a tennis racket - Correct answer: 12
# 419 - Predicted answer: 42 male and 23 female players. - Correct answer: basket ball
# 420 - Predicted answer: new york yankees. - Correct answer: boston braves
# 421 - Predicted answer: march 30, 1937 ) - Correct answer: splendor in grass
# 422 - Predicted answer: mars - Correct answer: debra winger
# 423 - Predicted answer: many u. s. and uk sitcoms have been successful there. - Correct answer: amos n andy
# 424 - Predicted answer: many other " addams families " exist all over the world. - Correct answer: john astin
# 425 - Predicted answer: leslie nielsen. - Correct answer: florence henderson
# 426 - Predicted answer: roger taylor - Correct answer: pete sampras
# 427 - Predicted answer: china is a cradle of civilization, - Correct answer: swimming
# 428 - Predicted answer: winning the gold medal at the summer olympic games - Correct answer: french
# 429 - Predicted answer: [PAD] - Correct answer: canoeing
# 430 - Predicted answer: 45 - Correct answer: three
# 431 - Predicted answer: menu that includes spam in every dish. - Correct answer: junk mail
# 432 - Predicted answer: private or personal libraries made up of written books appeared in classical greece - Correct answer: usa
# 433 - Predicted answer: guitarist chris stein. - Correct answer: rapture
# 434 - Predicted answer: the mediterranean sea - Correct answer: red sea
# 435 - Predicted answer: jennifer sue crawford - moluf ( nee walker ) and john dan crawford. - Correct answer: presley
# 436 - Predicted answer: sun yat sen - Correct answer: china
# 437 - Predicted answer: palestinian arabs - Correct answer: yasser arafat
# 438 - Predicted answer: al - fayed " - Correct answer: egypt
# 439 - Predicted answer: rangoon, british burma. - Correct answer: myanmar
# 440 - Predicted answer: d. w. griffith, charlie chaplin, mary pickford, and douglas fairbanks - Correct answer: chaplin
# 441 - Predicted answer: the cage of mad women " - Correct answer: nightclub
# 442 - Predicted answer: 71 % of earth's surface is covered with water. - Correct answer: 8
# 443 - Predicted answer: it is a unitary semi - presidential republic with the capital in paris, - Correct answer: reims
# 444 - Predicted answer: julie edwards, - Correct answer: julie andrews
# 445 - Predicted answer: tom t. hall - Correct answer: barbara eden
# 446 - Predicted answer: many artists are starting to release themselves independently for this reason. - Correct answer: atlantic
# 447 - Predicted answer: maybellene " - Correct answer: chess
# 448 - Predicted answer: what was the name of michael jackson's second wife? [SEP] michael joseph jackson - Correct answer: debbie rowe
# 449 - Predicted answer: modern historians generally consider sir robert walpole, - Correct answer: pittsburgh
# 450 - Predicted answer: it has a population of and an area of, making it the most sparsely - Correct answer: is
# 451 - Predicted answer: wembley stadium - Correct answer: philadelphia
# 452 - Predicted answer: since the 1981 inauguration of ronald reagan, - Correct answer: george w bush
# 453 - Predicted answer: the nazis sought to improve the stock of the germanic people - Correct answer: reinhard heidrich
# 454 - Predicted answer: andres bonifacio - Correct answer: marcos
# 455 - Predicted answer: the bagratid kingdom of armenia was restored in the 9th century. - Correct answer: earthquake
# 456 - Predicted answer: cuba. - Correct answer: texas
# 457 - Predicted answer: december 7, 1941. - Correct answer: december
# 458 - Predicted answer: cora henrietta crippen, - Correct answer: his wife
# 459 - Predicted answer: the ioc later declared that 94 of these events were olympic. - Correct answer: 21
# 460 - Predicted answer: liverpool, - Correct answer: new york
# 461 - Predicted answer: his assassination in november 1963. - Correct answer: shot
# 462 - Predicted answer: prohibits anyone from ever being elected to the presidency for a third full term. - Correct answer: nixon
# 463 - Predicted answer: jacqueline du pre. - Correct answer: daniel barenboim
# 464 - Predicted answer: helen jane buchan. - Correct answer: john buchan
# 465 - Predicted answer: 1912, - Correct answer: 1914
# 466 - Predicted answer: a second primary route is the trans - manchurian, - Correct answer: vladivostok
# 467 - Predicted answer: 42 - Correct answer: khyber pass
# 468 - Predicted answer: deepest - Correct answer: maldives
# 469 - Predicted answer: it is a unitary semi - presidential republic with the capital in paris, - Correct answer: louis xvi
# 470 - Predicted answer: simeon i achieved a string of victories over the byzantines. - Correct answer: bulgarian
# 471 - Predicted answer: the square was meant to serve as moscow's main marketplace. - Correct answer: st basil s
# 472 - Predicted answer: finland was incorporated into the russian empire - Correct answer: finland
# 473 - Predicted answer:  - Correct answer: hague
# 474 - Predicted answer: the state is governed by the communist party of china based in the capital of beijing. - Correct answer: mao zedong
# 475 - Predicted answer: catherine of aragon, - Correct answer: catherine parr
# 476 - Predicted answer: the dynasty was split between austrian and spanish branches. - Correct answer: switzerland
# 477 - Predicted answer: club of thirteen ' - Correct answer: ecology party
# 478 - Predicted answer: first - past - the - post voting method - Correct answer: first past post
# 479 - Predicted answer: chauvinism ; - Correct answer: chauvinism
# 480 - Predicted answer: ten - horsepower engines enabled a wide range of manufacturing machinery to be powered. - Correct answer: james watt
# 481 - Predicted answer: edith giovanna gassion ) - Correct answer: little sparrow
# 482 - Predicted answer: batch house, the hot end, and the cold end. - Correct answer: sand
# 483 - Predicted answer: organon, - Correct answer: fungus
# 484 - Predicted answer: tonoplastja raven - Correct answer: cellulose
# 485 - Predicted answer: a liquid is able to flow and take the shape of a container. - Correct answer: evaporation
# 486 - Predicted answer: science and islam, jim al - khalili - Correct answer: arithmetic
# 487 - Predicted answer: a force can cause an object with mass to change its velocity - Correct answer: friction
# 488 - Predicted answer: the female does most or all of the nest construction, - Correct answer: ornithology
# 489 - Predicted answer: modern non - avian reptiles inhabit every continent with the exception of antarctica - Correct answer: alligator
# 490 - Predicted answer: presence of seawater - Correct answer: kelp
# 491 - Predicted answer: diving mammals - Correct answer: muscle tissue
# 492 - Predicted answer: primates - Correct answer: cellulose
# 493 - Predicted answer: the difficulty of defining species is known as the species problem. - Correct answer: ant
# 494 - Predicted answer: behaviourism - Correct answer: ethology
# 495 - Predicted answer: rodents - Correct answer: squirrel
# 496 - Predicted answer: some leaves, such as bulb scales - Correct answer: leaf
# 497 - Predicted answer: mammalia, - Correct answer: beaver
# 498 - Predicted answer: crocodilians. - Correct answer: wisdom teeth
# 499 - Predicted answer: porosomes. - Correct answer: insulin
# 500 - Predicted answer: females - Correct answer: gluteus maximus
# 501 - Predicted answer: ovarian ligament. - Correct answer: corpus luteum
# 502 - Predicted answer: steroid hormones, - Correct answer: luteinizing hormone
# 503 - Predicted answer: steam. - Correct answer: oxygen
# 504 - Predicted answer: parent and the daughter nuclides - Correct answer: radon
# 505 - Predicted answer: dana classification - Correct answer: gypsum
# 506 - Predicted answer: eagle - Correct answer: neil armstrong
# 507 - Predicted answer: proteus and nereid - Correct answer: neptune
# 508 - Predicted answer: the milky way is estimated to contain 100 – 400 billion stars, - Correct answer: local galaxy
# 509 - Predicted answer: a force can cause an object with mass to change its velocity - Correct answer: gravitational force
# 510 - Predicted answer: oprah winfrey show, - Correct answer: color purple
# 511 - Predicted answer: hydrogen and helium - Correct answer: helium
# 512 - Predicted answer: number 10 is over three hundred years old and contains approximately one hundred rooms. - Correct answer: white
# 513 - Predicted answer: the country thereafter enjoyed relative peace and stability, - Correct answer: 57

# %%
correct_results = results.filter(lambda x: x['match'] is True)
print(f"\nWrong examples: ")
print_out = correct_results.map(lambda x, i: print(f"{i} - Predicted answer: {x['output']} - Correct answer: {x['correct_answer']}"), with_indices = True)
# Out:
# Loading cached processed dataset at /root/.cache/huggingface/datasets/trivia_qa/rc/1.1.0/c1b17d80bfdd2f43b13e4b5741847f704115379ecebcb21e0917d2e8ddaa1ff1/cache-421fda62a84502a9.arrow
# Wrong examples:
# 0 - Predicted answer: confucius - Correct answer: confucius
# HBox(children=(FloatProgress(value=0.0, max=66.0), HTML(value='')))
# 0 - Predicted answer: confucius - Correct answer: confucius
# 1 - Predicted answer: rio de janeiro, - Correct answer: rio de janeiro
# 2 - Predicted answer: the mendip hills - Correct answer: mendips
# 3 - Predicted answer: ub iwerks - Correct answer: ub iwerks
# 4 - Predicted answer: 692 - Correct answer: 692
# 5 - Predicted answer: spandau ballet. - Correct answer: spandau ballet
# 6 - Predicted answer: jude, - Correct answer: st jude
# 7 - Predicted answer: james woods. - Correct answer: james woods
# 8 - Predicted answer: beetroots - Correct answer: beetroot
# 9 - Predicted answer: muriel spark, - Correct answer: muriel spark
# 10 - Predicted answer: leeds, - Correct answer: leeds
# 11 - Predicted answer: davros, - Correct answer: davros
# 12 - Predicted answer: russia - Correct answer: russia
# 13 - Predicted answer: gargantua - Correct answer: gargantua
# 14 - Predicted answer: smersh. - Correct answer: smersh
# 15 - Predicted answer: jennifer aniston, - Correct answer: jennifer aniston
# 16 - Predicted answer: novak djokovic - Correct answer: novak djokovic
# 17 - Predicted answer: 1984 - Correct answer: 1984
# 18 - Predicted answer: forty - Correct answer: 40
# 19 - Predicted answer: king george iv - Correct answer: george fourth
# 20 - Predicted answer: charlie chan, - Correct answer: charlie chan
# 21 - Predicted answer: baku, - Correct answer: baku azerbaijan
# 22 - Predicted answer: henry ford - Correct answer: henry ford
# 23 - Predicted answer: island of ireland. - Correct answer: ireland
# 24 - Predicted answer: bikini atoll - Correct answer: bikini atoll
# 25 - Predicted answer: pakistan. - Correct answer: pakistan
# 26 - Predicted answer: madonna. - Correct answer: madonna
# 27 - Predicted answer: uk independence party - Correct answer: ukip
# 28 - Predicted answer: peninsular war, - Correct answer: peninsular war
# 29 - Predicted answer: 1066, - Correct answer: 1066
# 30 - Predicted answer: european bison - Correct answer: european bison
# 31 - Predicted answer: roddy doyle, - Correct answer: roddy doyle
# 32 - Predicted answer: anne sullivan, - Correct answer: anne sullivan
# 33 - Predicted answer: thomas de quincey, - Correct answer: thomas de quincy
# 34 - Predicted answer: arlene phillips - Correct answer: arlene phillips
# 35 - Predicted answer: cat stevens, - Correct answer: cat stevens
# 36 - Predicted answer: meet me in st. louis. - Correct answer: meet me in st louis
# 37 - Predicted answer: raphael, - Correct answer: raphael
# 38 - Predicted answer: steve miller band, - Correct answer: steve miller band
# 39 - Predicted answer: lauren bacall - Correct answer: lauren bacall
# 40 - Predicted answer: kilimanjaro, - Correct answer: kilimanjaro
# 41 - Predicted answer: niger. - Correct answer: niger
# 42 - Predicted answer: adolf hitler, - Correct answer: hitler
# 43 - Predicted answer: richard marx. - Correct answer: richard marx
# 44 - Predicted answer: john ford, - Correct answer: john ford
# 45 - Predicted answer: pink floyd - Correct answer: pink floyd
# 46 - Predicted answer: fiddler on the roof. - Correct answer: fiddler on roof
# 47 - Predicted answer: rudolf hess, - Correct answer: rudolf hess
# 48 - Predicted answer: japan, - Correct answer: japan
# 49 - Predicted answer: jelly roll morton - Correct answer: jelly roll morton
# 50 - Predicted answer: chicago, - Correct answer: chicago
# 51 - Predicted answer: perry mason - Correct answer: perry mason
# 52 - Predicted answer: massachusetts, - Correct answer: massachusetts
# 53 - Predicted answer: shine, - Correct answer: shine
# 54 - Predicted answer: new zealand - Correct answer: new zealand
# 55 - Predicted answer: 1905. - Correct answer: 1905
# 56 - Predicted answer: frank harris - Correct answer: frank harris
# 57 - Predicted answer: world war ii, - Correct answer: wwii
# 58 - Predicted answer: ub iwerks - Correct answer: ub iwerks
# 59 - Predicted answer: bobby vinton - Correct answer: bobby vinton
# 60 - Predicted answer: wisconsin. - Correct answer: wisconsin
# 61 - Predicted answer: bat - man " - Correct answer: batman
# 62 - Predicted answer: lee harvey oswald, - Correct answer: lee harvey oswald
# 63 - Predicted answer: the third crusade - Correct answer: third crusade
# 64 - Predicted answer: the battle of hastings - Correct answer: battle of hastings
# 65 - Predicted answer: four - Correct answer: four

# %%
# Turn it into a dataframe and view the result
dataframe = pd.DataFrame(trivia_qa_dataset) 
dataframe
# Out:
#                                                context       correct_answer  \
# 0    England is a country that is part of the Unite...             coventry
# 1    The Winter Olympic Games (French: Jeux olympiq...            norwegian
# 2    The East Coast Main Line (ECML) is a 393 mi  r...              mallard
# 3    Cricket is a bat-and-ball game played between ...        handling ball
# 4    Tannochbrae is a fictional town in Scotland wh...            dr finlay
# ..                                                 ...                  ...
# 575  In physics, a force is any interaction that, w...  gravitational force
# 576  Oprah Gail Winfrey (born January 29, 1954) is ...         color purple
# 577  A chemical element or element is a species of ...               helium
# 578  10 Downing Street, colloquially known in the U...                white
# 579  Argentina (;), officially the Argentine Republ...                   57
#
#                                       possible_answers  \
# 0    [Cofantre, Coventry (city), Coventry, Warwicks...
# 1    [Norwegain, Nowegian, Norwegian (disambiguatio...
# 2    [Mallard Duck, Mallards, Platyrhynchos, Mallar...
# 3                                  [Handling the ball]
# 4    [Dr Finlay, Dr. Finlay, Dr Findlay's Casebook,...
# ..                                                 ...
# 575  [Gravitational physics, Gravitation, Gravity, ...
# 576  [The Colour Purple, Colour Purple, Color Purpl...
# 577  [Solid Helium, Superfluid helium, Two fluid mo...
# 578  [White (Colour), Rgb(255, 255, 255), White, Wh...
# 579                                  [57, fifty-seven]
#
#                                               question
# 0     Where in England was actor Nigel Hawthorne born?
# 1    What nationality was three time Olympic gold m...
# 2    What is the name of the steam locomotive which...
# 3    In January 1957, Russell Endean became the fir...
# 4    Which fictional UK television doctor lives in ...
# ..                                                 ...
# 575  Which force is nothing more than the bending o...
# 576  In what film did Oprah Winfrey make her big sc...
# 577      What is the second lightest chemical element?
# 578  What colour is the number 10 on the door of 10...
# 579  What number in Bingo is sometimes referred to ...
#
# [580 rows x 4 columns]

# %%
print("Number of question and answers: ", len(dataframe))
dataframe.to_csv('TriviaQA.csv')
# Out:
# Number of question and answers:  580

# %%
context_trivia = dataframe['context'].to_list()
answers_trivia = dataframe['correct_answer'].to_list()
possible_answers_trivia = dataframe['possible_answers'].to_list()
questions_trivia = dataframe['question'].to_list()

# View some examples
print('\nContext:', context_trivia[5])
print()
print('Question:', questions_trivia[5])
print()
print('Answer:', answers_trivia[5])
print()
print('Possible Answers:', possible_answers_trivia[5])
# Out:
# Context: BBC Radio 1 is a British radio station operated by the British Broadcasting Corporation which also broadcasts internationally, specialising in modern and current popular music and chart hits throughout the day. Radio 1 provides alternative genres after 7:00 pm, including electronic dance, hip hop, rock, indie or interviews. It is aimed primarily at the 15–29 age group,  although the average age of the UK audience in 2008 was 33.  BBC Radio 1 started 24-hour broadcasting on 1 May 1991.   History   First broadcast   Radio 1 was established in 1967 (along with the more middle of the road BBC Radio 2) as a successor to the BBC Light Programme, which had broadcast popular music and other entertainment since 1945. Radio 1 was conceived as a direct response to the popularity of offshore pirate radio stations such as Radio Caroline and Radio London, which had been outlawed by Act of Parliament.  Radio 1 was launched at 7:00 am on Saturday 30 September 1967.  The first disc jockey to broadcast on the new station was Tony Blackburn, whose cheery style, first heard on Radio Caroline and Radio London, won him the prime slot on what became known as the "Radio 1 Breakfast Show". The first words on Radio 1 – after a countdown by the Controller of Radios 1 and 2, Robin Scott, and a jingle, recorded at PAMS in Dallas, Texas, beginning "The voice of Radio 1" – were "... And, good morning everyone. Welcome to the exciting new sound of Radio 1". This was the first use of US-style jingles on BBC radio, but the style was familiar to listeners who were acquainted with Blackburn and other DJs from their days on pirate radio. The first complete record played on Radio 1 was "Flowers in the Rain" by The Move. The second single was "Massachusetts" by The Bee Gees. The breakfast show remains the most prized slot in the Radio 1 schedule, with every change of breakfast show presenter exciting considerable media interest.  The initial rota of staff included John Peel and a gaggle of others, some hired from pirates, such as Keith Skues, Ed Stewart, Mike Raven, David Ryder, Jim Fisher, Jimmy Young, Dave Cash, Kenny Everett, Simon Dee, Terry Wogan, Duncan Johnson, Doug Crawford, Tommy Vance, Chris Denning, Emperor Rosko, Pete Murray, and Bob Holness. Many of the most popular pirate radio voices, such as Simon Dee, had only a one-hour slot per week, ("Midday Spin.")  Annie Nightingale, who joined in 1970, was Britain's first female DJ and is now the longest serving presenter, having constantly evolved her musical tastes with the times.   1970s peak   Initially, the station was unpopular with some of its target audience who, it is claimed, disliked the fact that much of its airtime was shared with Radio 2 and that it was less unequivocally aimed at a young audience than the offshore stations, with some DJs such as Jimmy Young being in their 40s. The very fact that it was part of an "establishment" institution such as the BBC was a turn-off for some, and needle time restrictions prevented it from playing as many records as offshore stations had. It also had limited finances (partially because the BBC did not increase its licence fee to fund the new station) and often, as in January 1975, suffered disproportionately when the BBC had to make financial cutbacks, strengthening an impression that it was regarded as a lower priority by senior BBC executives.  Despite this, it gained massive audiences, becoming the most listened to station in the world with audiences of over 10 million claimed for some of its shows (up to 20 million for some of the combined Radio 1 and Radio 2 shows). In the early-mid-1970s Radio 1 presenters were rarely out of the British tabloids, thanks to the Publicity Department's high profile work. The popularity of Radio 1's touring summer live broadcasts the Radio 1 Roadshow - usually as part of the BBC 'Radio Weeks' promotions that took Radio 1, 2 and 4 shows on the road - drew some of the largest crowds of the decade. The station undou ...
#
# Question: Who became the host of the BBC Radio 1 weekday breakfast show in September 2012?
#
# Answer: nick grimshaw
#
# Possible Answers: ['Nick Grimshaw']

# %% [markdown]
# **TEST MODEL ON EXAMPLES**

# %%
# View the predicted answer of the second example
question_trivia = questions_trivia[5]
text_trivia = context_trivia[5]

question_answering_trivia(question_trivia, text_trivia)
# Out:
# Question: Who became the host of the BBC Radio 1 weekday breakfast show in September 2012?
#
# Answer: "tony blackburn,"
# Exact Match 0 | F1 score 0.0007162041181736795

# %%
random_num = np.random.randint(0,len(questions_trivia))
random_question_trivia = questions_trivia[random_num]
random_text_trivia = context_trivia[random_num]

question_answering_trivia(random_question_trivia, random_text_trivia)
# Out:
# Question: In which year was the Juilliard School founded in New York?
#
# Answer: "1905. it is informally referred to as juilliard. the school trains about 850 undergraduate and graduate students in dance, drama, and music. it is widely regarded as one of the world's leading music schools, with some of the most prestigious arts programs. history in 1905, the institute of musical art was founded on the premise that the united states did not have a premier music school and too many students were going to europe to study music. at its formation, the institute was located in manhattan at fifth avenue and 12th street. during its first year, the institute enrolled 500 students. it moved in 1910 to claremont avenue in the morningside heights neighborhood of manhattan, onto a property purchased from bloomingdale insane asylum. in 1920, the juilliard foundation was created, named after textile merchant augustus d. juilliard, who bequeathed a substantial amount of money for the advancement of music in the united states. in 1924, the foundation purchased the vanderbilt family guesthouse at 49 east 52nd street to start the juilliard graduate school. in 1926, it merged partially with the institute of musical art with a common president, the columbia university professor john erskine."
# Exact Match 0 | F1 score 0.16960784313725488
